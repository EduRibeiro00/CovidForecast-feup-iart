# %% [markdown]
# # Covid 19 Analysis

# %%
# %matplotlib inline

import math
import time
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
import seaborn as sb
import pandas as pd
from sklearn.model_selection import GridSearchCV, RandomizedSearchCV, train_test_split, cross_val_score, learning_curve
from sklearn.ensemble import RandomForestRegressor
from sklearn.datasets import load_iris, load_digits
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

# %% [markdown]
# ### 3) Prediction and Regression
# #### 3.1) Random Forest
# - - -

# %%
# load previously processed information into dataframe
df = pd.read_csv('data/covid_19_world_processed.csv', delimiter=',')
df
# Out:
#          Country/Region      Lat  Lat_norm      Long  Long_norm        Date  \
# 0           Afghanistan  33.0000  0.471083   65.0000   0.597360  2020-01-22
# 1               Albania  41.1533  0.798304   20.1683  -0.039787  2020-01-22
# 2      Alberta (Canada)  53.9333  1.311212 -116.5765  -1.983201  2020-01-22
# 3               Algeria  28.0339  0.271776    1.6596  -0.302833  2020-01-22
# 4               Andorra  42.5063  0.852605    1.5218  -0.304791  2020-01-22
# ...                 ...      ...       ...       ...        ...         ...
# 30619    Yukon (Canada)  64.2823  1.726554 -135.0000  -2.245035  2020-05-16
# 30620    Yunnan (China)  24.9740  0.148971  101.4870   1.115912  2020-05-16
# 30621            Zambia -15.4167 -1.472053   28.2833   0.075543  2020-05-16
# 30622  Zhejiang (China)  29.1832  0.317901  120.0934   1.380346  2020-05-16
# 30623          Zimbabwe -20.0000 -1.655997   30.0000   0.099941  2020-05-16
#
#        Num_days_from_begin  Num_days_from_begin_norm  Confirmed  Deaths  ...  \
# 0                        0                 -1.717183          0       0  ...
# 1                        0                 -1.717183          0       0  ...
# 2                        0                 -1.717183          0       0  ...
# 3                        0                 -1.717183          0       0  ...
# 4                        0                 -1.717183          0       0  ...
# ...                    ...                       ...        ...     ...  ...
# 30619                  115                  1.717183         11       0  ...
# 30620                  115                  1.717183        185       2  ...
# 30621                  115                  1.717183        679       7  ...
# 30622                  115                  1.717183       1268       1  ...
# 30623                  115                  1.717183         42       4  ...
#
#        Confirmed_inc_day_before  Confirmed_inc_day_before_norm  Deaths_inc  \
# 0                           NaN                            NaN         0.0
# 1                           NaN                            NaN         0.0
# 2                           NaN                            NaN         0.0
# 3                           NaN                            NaN         0.0
# 4                           NaN                            NaN         0.0
# ...                         ...                            ...         ...
# 30619                       0.0                      -0.116999         0.0
# 30620                       0.0                      -0.116999         0.0
# 30621                       0.0                      -0.116999         0.0
# 30622                       0.0                      -0.116999         0.0
# 30623                       5.0                      -0.113089         0.0
#
#        Deaths_inc_norm  Deaths_inc_day_before  Deaths_inc_day_before_norm  \
# 0            -0.110666                    NaN                         NaN
# 1            -0.110666                    NaN                         NaN
# 2            -0.110666                    NaN                         NaN
# 3            -0.110666                    NaN                         NaN
# 4            -0.110666                    NaN                         NaN
# ...                ...                    ...                         ...
# 30619        -0.110666                    0.0                   -0.110177
# 30620        -0.110666                    0.0                   -0.110177
# 30621        -0.110666                    0.0                   -0.110177
# 30622        -0.110666                    0.0                   -0.110177
# 30623        -0.110666                    0.0                   -0.110177
#
#        Recovered_inc  Recovered_inc_norm  Recovered_inc_day_before  \
# 0                0.0           -0.121130                       NaN
# 1                0.0           -0.121130                       NaN
# 2                NaN                 NaN                       NaN
# 3                0.0           -0.121130                       NaN
# 4                0.0           -0.121130                       NaN
# ...              ...                 ...                       ...
# 30619            NaN                 NaN                       NaN
# 30620            0.0           -0.121130                       0.0
# 30621           59.0            0.003578                       0.0
# 30622            0.0           -0.121130                       0.0
# 30623            0.0           -0.121130                       0.0
#
#        Recovered_inc_day_before_norm
# 0                                NaN
# 1                                NaN
# 2                                NaN
# 3                                NaN
# 4                                NaN
# ...                              ...
# 30619                            NaN
# 30620                      -0.121373
# 30621                      -0.121373
# 30622                      -0.121373
# 30623                      -0.121373
#
# [30624 rows x 23 columns]

# %%
# get the inputs of the data for the machine learning algorithm
inputs = df[["Lat_norm", "Long_norm", "Num_days_from_begin_norm"]].values
inputs
# Out:
# array([[ 0.47108303,  0.59735963, -1.71718314],
#        [ 0.79830423, -0.03978737, -1.71718314],
#        [ 1.3112115 , -1.98320106, -1.71718314],
#        ...,
#        [-1.47205293,  0.07554281,  1.71718314],
#        [ 0.31790115,  1.38034566,  1.71718314],
#        [-1.65599721,  0.09994051,  1.71718314]])

# %% [markdown]
# #### 3.1.1) Regression for Confirmed Cases
# - - -

# %%
# get the output for the machine learning algorithm (confirmed cases)
outputs = df["Confirmed"].values
outputs
# Out:
# array([   0,    0,    0, ...,  679, 1268,   42])

# %%
# split the data into training and testing sets
in_conf_train, in_conf_test, out_conf_train, out_conf_test = train_test_split(inputs, outputs, test_size=0.25, shuffle=True)

# NOTE: actually, the "testing" set will be used for "manual" testing and plotting, while the training set will be
# further divided in training and testing sets, in order to perform k-fold cross validation.

# %%
# create Random Forest Regressor instance, and check the hyper parameters
rf = RandomForestRegressor()
rf.get_params()
# Out:
# {'bootstrap': True,
#  'ccp_alpha': 0.0,
#  'criterion': 'mse',
#  'max_depth': None,
#  'max_features': 'auto',
#  'max_leaf_nodes': None,
#  'max_samples': None,
#  'min_impurity_decrease': 0.0,
#  'min_impurity_split': None,
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'min_weight_fraction_leaf': 0.0,
#  'n_estimators': 100,
#  'n_jobs': None,
#  'oob_score': False,
#  'random_state': None,
#  'verbose': 0,
#  'warm_start': False}

# %%
# do hyper parameter tuning with the Random Forest, using cross validation
param_grid = {
    'bootstrap': [True],
    'max_depth': [80, 90, 100, 110],
    'max_features': [2, 3],
    'min_samples_leaf': [3, 4, 5],
    'min_samples_split': [8, 10, 12],
    'n_estimators': [100, 200, 300, 1000]
}

start = time.time()

#search = GridSearchCV(estimator=rf, param_grid=param_grid, cv=3, n_jobs=-1, verbose=2)
search = RandomizedSearchCV(rf, param_grid, scoring='neg_mean_squared_error', cv=3, return_train_score=True, n_jobs=-1, n_iter=10, verbose=1)
search.fit(in_conf_train, out_conf_train)
end = time.time()
elapsed_time = end - start
print('Elapsed time: {}mins'.format(elapsed_time / 60))
print('Best score: {}'.format(search.best_score_))
print('Best parameters: {}'.format(search.best_params_))
search.best_estimator_
rf_estimator = search.best_estimator_
rf_estimator


#rf_estimator = RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
                      #max_depth=100, max_features=3, max_leaf_nodes=None,
                      #max_samples=None, min_impurity_decrease=0.0,
                      #min_impurity_split=None, min_samples_leaf=3,
                      #min_samples_split=8, min_weight_fraction_leaf=0.0,
                      #n_estimators=100, n_jobs=None, oob_score=False,
                      #random_state=None, verbose=0, warm_start=False)
#rf_estimator.fit(in_conf_train, out_conf_train)
# Out:
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  30 out of  30 | elapsed:  5.6min finished
# Elapsed time: 5.845779534180959mins
# Best score: -19703833.531192064
# Best parameters: {'n_estimators': 300, 'min_samples_split': 8, 'min_samples_leaf': 3, 'max_features': 3, 'max_depth': 90, 'bootstrap': True}
# RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
#                       max_depth=90, max_features=3, max_leaf_nodes=None,
#                       max_samples=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=3,
#                       min_samples_split=8, min_weight_fraction_leaf=0.0,
#                       n_estimators=300, n_jobs=None, oob_score=False,
#                       random_state=None, verbose=0, warm_start=False)

# %%
rf_estimator_pred = rf_estimator.predict(in_conf_test)
plt.plot(out_conf_test)
plt.plot(rf_estimator_pred)
plt.legend(['Input Data', 'Random Forest Predictions'])
print('MAE:', mean_absolute_error(out_conf_test, rf_estimator_pred))
print('MSE:',mean_squared_error(out_conf_test, rf_estimator_pred))
print('RMSE:', math.sqrt(mean_squared_error(out_conf_test, rf_estimator_pred)))
print('R^2:', r2_score(out_conf_test, rf_estimator_pred))
# Out:
# MAE: 205.53200101985658
# MSE: 2235617.7804334657
# RMSE: 1495.1982411819063
# R^2: 0.99723228898194

# %%
rf_estimator_2 = RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
                      max_depth=100, max_features=3, max_leaf_nodes=None,
                      max_samples=None, min_impurity_decrease=0.0,
                      min_impurity_split=None, min_samples_leaf=3,
                      min_samples_split=8, min_weight_fraction_leaf=0.0,
                      n_estimators=100, n_jobs=None, oob_score=False,
                      random_state=None, verbose=0, warm_start=False)

cv_scores = cross_val_score(rf_estimator_2, inputs, outputs, cv=10)
plt.hist(cv_scores)
plt.title('Average score: {}'.format(np.mean(cv_scores)))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-90-d9c22a905950> in <module>
#       7                       random_state=None, verbose=0, warm_start=False)
#       8
# ----> 9 cv_scores = cross_val_score(rf_estimator_2, inputs, outputs, cv=10)
#      10 plt.hist(cv_scores)
#      11 plt.title('Average score: {}'.format(np.mean(cv_scores)))
#
# /opt/miniconda3/envs/iart/lib/python3.7/site-packages/sklearn/model_selection/_validation.py in cross_val_score(estimator, X, y, groups, scoring, cv, n_jobs, verbose, fit_params, pre_dispatch, error_score)
#     388                                 fit_params=fit_params,
#     389                                 pre_dispatch=pre_dispatch,
# --> 390                                 error_score=error_score)
#     391     return cv_results['test_score']
#     392
#
# /opt/miniconda3/envs/iart/lib/python3.7/site-packages/sklearn/model_selection/_validation.py in cross_validate(estimator, X, y, groups, scoring, cv, n_jobs, verbose, fit_params, pre_dispatch, return_train_score, return_estimator, error_score)
#     234             return_times=True, return_estimator=return_estimator,
#     235             error_score=error_score)
# --> 236         for train, test in cv.split(X, y, groups))
#     237
#     238     zipped_scores = list(zip(*scores))
#
# /opt/miniconda3/envs/iart/lib/python3.7/site-packages/joblib/parallel.py in __call__(self, iterable)
#    1002             # remaining jobs.
#    1003             self._iterating = False
# -> 1004             if self.dispatch_one_batch(iterator):
#    1005                 self._iterating = self._original_iterator is not None
#    1006
#
# /opt/miniconda3/envs/iart/lib/python3.7/site-packages/joblib/parallel.py in dispatch_one_batch(self, iterator)
#     833                 return False
#     834             else:
# --> 835                 self._dispatch(tasks)
#     836                 return True
#     837
#
# /opt/miniconda3/envs/iart/lib/python3.7/site-packages/joblib/parallel.py in _dispatch(self, batch)
#     752         with self._lock:
#     753             job_idx = len(self._jobs)
# --> 754             job = self._backend.apply_async(batch, callback=cb)
#     755             # A job can complete so quickly than its callback is
#     756             # called before we get here, causing self._jobs to
#
# /opt/miniconda3/envs/iart/lib/python3.7/site-packages/joblib/_parallel_backends.py in apply_async(self, func, callback)
#     207     def apply_async(self, func, callback=None):
#     208         """Schedule a func to be run"""
# --> 209         result = ImmediateResult(func)
#     210         if callback:
#     211             callback(result)
#
# /opt/miniconda3/envs/iart/lib/python3.7/site-packages/joblib/_parallel_backends.py in __init__(self, batch)
#     588         # Don't delay the application, to avoid keeping the input
#     589         # arguments in memory
# --> 590         self.results = batch()
#     591
#     592     def get(self):
#
# /opt/miniconda3/envs/iart/lib/python3.7/site-packages/joblib/parallel.py in __call__(self)
#     254         with parallel_backend(self._backend, n_jobs=self._n_jobs):
#     255             return [func(*args, **kwargs)
# --> 256                     for func, args, kwargs in self.items]
#     257
#     258     def __len__(self):
#
# /opt/miniconda3/envs/iart/lib/python3.7/site-packages/joblib/parallel.py in <listcomp>(.0)
#     254         with parallel_backend(self._backend, n_jobs=self._n_jobs):
#     255             return [func(*args, **kwargs)
# --> 256                     for func, args, kwargs in self.items]
#     257
#     258     def __len__(self):
#
# /opt/miniconda3/envs/iart/lib/python3.7/site-packages/sklearn/model_selection/_validation.py in _fit_and_score(estimator, X, y, scorer, train, test, verbose, parameters, fit_params, return_train_score, return_parameters, return_n_test_samples, return_times, return_estimator, error_score)
#     513             estimator.fit(X_train, **fit_params)
#     514         else:
# --> 515             estimator.fit(X_train, y_train, **fit_params)
#     516
#     517     except Exception as e:
#
# /opt/miniconda3/envs/iart/lib/python3.7/site-packages/sklearn/ensemble/_forest.py in fit(self, X, y, sample_weight)
#     381                     verbose=self.verbose, class_weight=self.class_weight,
#     382                     n_samples_bootstrap=n_samples_bootstrap)
# --> 383                 for i, t in enumerate(trees))
#     384
#     385             # Collect newly grown trees
#
# /opt/miniconda3/envs/iart/lib/python3.7/site-packages/joblib/parallel.py in __call__(self, iterable)
#    1005                 self._iterating = self._original_iterator is not None
#    1006
# -> 1007             while self.dispatch_one_batch(iterator):
#    1008                 pass
#    1009
#
# /opt/miniconda3/envs/iart/lib/python3.7/site-packages/joblib/parallel.py in dispatch_one_batch(self, iterator)
#     833                 return False
#     834             else:
# --> 835                 self._dispatch(tasks)
#     836                 return True
#     837
#
# /opt/miniconda3/envs/iart/lib/python3.7/site-packages/joblib/parallel.py in _dispatch(self, batch)
#     752         with self._lock:
#     753             job_idx = len(self._jobs)
# --> 754             job = self._backend.apply_async(batch, callback=cb)
#     755             # A job can complete so quickly than its callback is
#     756             # called before we get here, causing self._jobs to
#
# /opt/miniconda3/envs/iart/lib/python3.7/site-packages/joblib/_parallel_backends.py in apply_async(self, func, callback)
#     207     def apply_async(self, func, callback=None):
#     208         """Schedule a func to be run"""
# --> 209         result = ImmediateResult(func)
#     210         if callback:
#     211             callback(result)
#
# /opt/miniconda3/envs/iart/lib/python3.7/site-packages/joblib/_parallel_backends.py in __init__(self, batch)
#     588         # Don't delay the application, to avoid keeping the input
#     589         # arguments in memory
# --> 590         self.results = batch()
#     591
#     592     def get(self):
#
# /opt/miniconda3/envs/iart/lib/python3.7/site-packages/joblib/parallel.py in __call__(self)
#     254         with parallel_backend(self._backend, n_jobs=self._n_jobs):
#     255             return [func(*args, **kwargs)
# --> 256                     for func, args, kwargs in self.items]
#     257
#     258     def __len__(self):
#
# /opt/miniconda3/envs/iart/lib/python3.7/site-packages/joblib/parallel.py in <listcomp>(.0)
#     254         with parallel_backend(self._backend, n_jobs=self._n_jobs):
#     255             return [func(*args, **kwargs)
# --> 256                     for func, args, kwargs in self.items]
#     257
#     258     def __len__(self):
#
# /opt/miniconda3/envs/iart/lib/python3.7/site-packages/sklearn/ensemble/_forest.py in _parallel_build_trees(tree, forest, X, y, sample_weight, tree_idx, n_trees, verbose, class_weight, n_samples_bootstrap)
#     163             curr_sample_weight *= compute_sample_weight('balanced', y, indices)
#     164
# --> 165         tree.fit(X, y, sample_weight=curr_sample_weight, check_input=False)
#     166     else:
#     167         tree.fit(X, y, sample_weight=sample_weight, check_input=False)
#
# /opt/miniconda3/envs/iart/lib/python3.7/site-packages/sklearn/tree/_classes.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#    1223             sample_weight=sample_weight,
#    1224             check_input=check_input,
# -> 1225             X_idx_sorted=X_idx_sorted)
#    1226         return self
#    1227
#
# /opt/miniconda3/envs/iart/lib/python3.7/site-packages/sklearn/tree/_classes.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     365                                            min_impurity_split)
#     366
# --> 367         builder.build(self.tree_, X, y, sample_weight, X_idx_sorted)
#     368
#     369         if self.n_outputs_ == 1 and is_classifier(self):
#
# KeyboardInterrupt:

# %%
usa_df = df.loc[df["Country/Region"] == "US"]
usa_inputs = usa_df[["Lat_norm", "Long_norm", "Num_days_from_begin_norm"]].values
usa_outputs = usa_df["Confirmed"].values
days_list = df["Num_days_from_begin"].unique()
usa_pred_output = rf_estimator.predict(usa_inputs) 

first_day = df["Date"].min()
last_day = df["Date"].max()

print('MAE:', mean_absolute_error(usa_outputs, usa_pred_output))
print('MSE:',mean_squared_error(usa_outputs, usa_pred_output))
print('RMSE:', math.sqrt(mean_squared_error(usa_outputs, usa_pred_output)))
print('R^2:', r2_score(usa_outputs, usa_pred_output))

plt.plot(days_list, usa_outputs, color='blue', label="Actual Confirmed Cases")
plt.plot(days_list, usa_pred_output, color='green', label="Predicted (Random Forest)")
plt.xlabel("Number of days since {}".format(first_day))
plt.ylabel("# of Cases")
plt.title("USA Confirmed Cases vs Prediction from Random Forest Regressor (as of {})".format(last_day))
plt.legend()
# Out:
# MAE: 353393.7827777383
# MSE: 354178730678.4659
# RMSE: 595129.171422865
# R^2: -0.5265179759053822

# %%
spain_df = df.loc[df["Country/Region"] == "Spain"]
spain_inputs = spain_df[["Lat_norm", "Long_norm", "Num_days_from_begin_norm"]].values
spain_outputs = spain_df["Confirmed"].values
days_list = df["Num_days_from_begin"].unique()
spain_pred_output = rf_estimator.predict(spain_inputs) 

print('MAE:', mean_absolute_error(spain_outputs, spain_pred_output))
print('MSE:',mean_squared_error(spain_outputs, spain_pred_output))
print('RMSE:', math.sqrt(mean_squared_error(spain_outputs, spain_pred_output)))
print('R^2:', r2_score(spain_outputs, spain_pred_output))

first_day = df["Date"].min()
last_day = df["Date"].max()
plt.plot(days_list, spain_outputs, color='blue', label="Actual Confirmed Cases")
plt.plot(days_list, spain_pred_output, color='green', label="Predicted (Random Forest)")
plt.xlabel("Number of days since {}".format(first_day))
plt.ylabel("# of Cases")
plt.title("Spain Confirmed Cases vs Prediction from Random Forest Regressor (as of {})".format(last_day))
plt.legend()

# %%
brazil_df = df.loc[df["Country/Region"] == "Brazil"]
brazil_inputs = brazil_df[["Lat_norm", "Long_norm", "Num_days_from_begin_norm"]].values
brazil_outputs = brazil_df["Confirmed"].values
days_list = df["Num_days_from_begin"].unique()
brazil_pred_output = rf_estimator.predict(brazil_inputs)

print('MAE:', mean_absolute_error(brazil_outputs, brazil_pred_output))
print('MSE:',mean_squared_error(brazil_outputs, brazil_pred_output))
print('RMSE:', math.sqrt(mean_squared_error(brazil_outputs, brazil_pred_output)))
print('R^2:', r2_score(brazil_outputs, brazil_pred_output))

first_day = df["Date"].min()
last_day = df["Date"].max()
plt.plot(days_list, brazil_outputs, color='blue', label="Actual Confirmed Cases")
plt.plot(days_list, brazil_pred_output, color='green', label="Predicted (Random Forest)")
plt.xlabel("Number of days since {}".format(first_day))
plt.ylabel("# of Cases")
plt.title("Brazil Confirmed Cases vs Prediction from Random Forest Regressor (as of {})".format(last_day))
plt.legend()

# %%
portugal_df = df.loc[df["Country/Region"] == "Portugal"]
portugal_inputs = portugal_df[["Lat_norm", "Long_norm", "Num_days_from_begin_norm"]].values
portugal_outputs = portugal_df["Confirmed"].values
days_list = df["Num_days_from_begin"].unique()
portugal_pred_output = rf_estimator.predict(portugal_inputs)

print('MAE:', mean_absolute_error(portugal_outputs, portugal_pred_output))
print('MSE:',mean_squared_error(portugal_outputs, portugal_pred_output))
print('RMSE:', math.sqrt(mean_squared_error(portugal_outputs, portugal_pred_output)))
print('R^2:', r2_score(portugal_outputs, portugal_pred_output))

first_day = df["Date"].min()
last_day = df["Date"].max()
plt.plot(days_list, portugal_outputs, color='blue', label="Actual Confirmed Cases")
plt.plot(days_list, portugal_pred_output, color='green', label="Predicted (Random Forest)")
plt.xlabel("Number of days since {}".format(first_day))
plt.ylabel("# of Cases")
plt.title("Portugal Confirmed Cases vs Prediction from Random Forest Regressor (as of {})".format(last_day))
plt.legend()

# %%
# learning curve
rf_estimator_2 = RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
                      max_depth=100, max_features=3, max_leaf_nodes=None,
                      max_samples=None, min_impurity_decrease=0.0,
                      min_impurity_split=None, min_samples_leaf=3,
                      min_samples_split=8, min_weight_fraction_leaf=0.0,
                      n_estimators=100, n_jobs=None, oob_score=False,
                      random_state=None, verbose=0, warm_start=False)

train_sizes, train_scores, test_scores = learning_curve(estimator=rf_estimator_2, X=inputs, y=outputs,                                      groups=None, 
                                       train_sizes=np.array([0.1, 0.33, 0.55, 0.78, 1. ]),
                                       cv=None, scoring=None, exploit_incremental_learning=False, 
                                       n_jobs=None, pre_dispatch='all', verbose=0, shuffle=True,
                                       random_state=None, error_score=np.nan, return_times=False)

train_scores_mean = train_scores.mean(axis=1)
test_scores_mean = test_scores.mean(axis=1)

plt.plot(train_sizes, train_scores_mean, label='Training score')
plt.plot(train_sizes, test_scores_mean, label='Test score')

plt.ylabel('Score', fontsize=14)
plt.xlabel('Training set size', fontsize=14)
title = 'Learning curves for a ' + str(rf_estimator_2).split('(')[0] + ' model'
plt.title(title, fontsize=18, y=1.03)
plt.legend()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-89-ff215fd7cf82> in <module>
#      18 plt.ylabel('Score', fontsize=14)
#      19 plt.xlabel('Training set size', fontsize=14)
# ---> 20 title = 'Learning curves for a ' + str(rf_estimator).split('(')[0] + ' model'
#      21 plt.title(title, fontsize=18, y=1.03)
#      22 plt.legend()
#
# NameError: name 'rf_estimator' is not defined

# %% [markdown]
# # NON NORMALIZED

# %%
# get the inputs of the data for the machine learning algorithm
inputs = df[["Lat", "Long", "Num_days_from_begin"]].values
inputs
# Out:
# array([[  33.    ,   65.    ,    0.    ],
#        [  41.1533,   20.1683,    0.    ],
#        [  53.9333, -116.5765,    0.    ],
#        ...,
#        [ -15.4167,   28.2833,  115.    ],
#        [  29.1832,  120.0934,  115.    ],
#        [ -20.    ,   30.    ,  115.    ]])

# %%
# split the data into training and testing sets
in_conf_train, in_conf_test, out_conf_train, out_conf_test = train_test_split(inputs, outputs, test_size=0.25, shuffle=True)

# NOTE: actually, the "testing" set will be used for "manual" testing and plotting, while the training set will be
# further divided in training and testing sets, in order to perform k-fold cross validation.

# %%
# do hyper parameter tuning with the Random Forest, using cross validation
param_grid = {
    'bootstrap': [True],
    'max_depth': [80, 90, 100, 110],
    'max_features': [2, 3],
    'min_samples_leaf': [3, 4, 5],
    'min_samples_split': [8, 10, 12],
    'n_estimators': [100, 200, 300, 1000]
}

start = time.time()

#search = GridSearchCV(estimator=rf, param_grid=param_grid, cv=3, n_jobs=-1, verbose=2)
search = RandomizedSearchCV(RandomForestRegressor(), param_grid, scoring='neg_mean_squared_error', cv=3, return_train_score=True, n_jobs=-1, n_iter=10, verbose=1)
search.fit(in_conf_train, out_conf_train)
end = time.time()
elapsed_time = end - start
print('Elapsed time: {}mins'.format(elapsed_time / 60))
print('Best score: {}'.format(search.best_score_))
print('Best parameters: {}'.format(search.best_params_))
search.best_estimator_
rf_estimator = search.best_estimator_
rf_estimator

#rf_estimator = RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
                      #max_depth=100, max_features=3, max_leaf_nodes=None,
                      #max_samples=None, min_impurity_decrease=0.0,
                      #min_impurity_split=None, min_samples_leaf=3,
                      #min_samples_split=8, min_weight_fraction_leaf=0.0,
                      #n_estimators=100, n_jobs=None, oob_score=False,
                      #random_state=None, verbose=0, warm_start=False)
#rf_estimator.fit(in_conf_train, out_conf_train)
# Out:
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  30 out of  30 | elapsed:  5.2min finished
# Elapsed time: 5.55018965403239mins
# Best score: -16961458.224204775
# Best parameters: {'n_estimators': 300, 'min_samples_split': 8, 'min_samples_leaf': 3, 'max_features': 3, 'max_depth': 90, 'bootstrap': True}
# RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
#                       max_depth=90, max_features=3, max_leaf_nodes=None,
#                       max_samples=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=3,
#                       min_samples_split=8, min_weight_fraction_leaf=0.0,
#                       n_estimators=300, n_jobs=None, oob_score=False,
#                       random_state=None, verbose=0, warm_start=False)

# %%
rf_estimator_pred = rf_estimator.predict(in_conf_test)
plt.plot(out_conf_test)
plt.plot(rf_estimator_pred)
plt.legend(['Input Data (Non normalized)', 'Random Forest Predictions'])
print('MAE:', mean_absolute_error(out_conf_test, rf_estimator_pred))
print('MSE:',mean_squared_error(out_conf_test, rf_estimator_pred))
print('RMSE:', math.sqrt(mean_squared_error(out_conf_test, rf_estimator_pred)))
print('R^2:', r2_score(out_conf_test, rf_estimator_pred))
# Out:
# MAE: 246.83397161248993
# MSE: 7630748.288524556
# RMSE: 2762.380909383164
# R^2: 0.9962133949059933

# %%
rf_estimator_2 = RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
                      max_depth=100, max_features=3, max_leaf_nodes=None,
                      max_samples=None, min_impurity_decrease=0.0,
                      min_impurity_split=None, min_samples_leaf=3,
                      min_samples_split=8, min_weight_fraction_leaf=0.0,
                      n_estimators=100, n_jobs=None, oob_score=False,
                      random_state=None, verbose=0, warm_start=False)

cv_scores = cross_val_score(rf_estimator_2, inputs, outputs, cv=10)
plt.hist(cv_scores)
plt.title('Average score: {}'.format(np.mean(cv_scores)))
# Out:
# Text(0.5, 1.0, 'Average score: -1.0786982517504593')

# %%
usa_df = df.loc[df["Country/Region"] == "US"]
usa_inputs = usa_df[["Lat", "Long", "Num_days_from_begin"]].values
usa_outputs = usa_df["Confirmed"].values
days_list = df["Num_days_from_begin"].unique()
usa_pred_output = rf_estimator.predict(usa_inputs) 

first_day = df["Date"].min()
last_day = df["Date"].max()

print('MAE:', mean_absolute_error(usa_outputs, usa_pred_output))
print('MSE:',mean_squared_error(usa_outputs, usa_pred_output))
print('RMSE:', math.sqrt(mean_squared_error(usa_outputs, usa_pred_output)))
print('R^2:', r2_score(usa_outputs, usa_pred_output))

plt.plot(days_list, usa_outputs, color='blue', label="Actual Confirmed Cases")
plt.plot(days_list, usa_pred_output, color='green', label="Predicted (Random Forest)")
plt.xlabel("Number of days since {}".format(first_day))
plt.ylabel("# of Cases")
plt.title("USA Confirmed Cases vs Prediction from Random Forest Regressor (as of {})".format(last_day))
plt.legend()

# %%
spain_df = df.loc[df["Country/Region"] == "Spain"]
spain_inputs = spain_df[["Lat", "Long", "Num_days_from_begin"]].values
spain_outputs = spain_df["Confirmed"].values
days_list = df["Num_days_from_begin"].unique()
spain_pred_output = rf_estimator.predict(spain_inputs) 

first_day = df["Date"].min()
last_day = df["Date"].max()

print('MAE:', mean_absolute_error(spain_outputs, spain_pred_output))
print('MSE:',mean_squared_error(spain_outputs, spain_pred_output))
print('RMSE:', math.sqrt(mean_squared_error(spain_outputs, spain_pred_output)))
print('R^2:', r2_score(spain_outputs, spain_pred_output))

plt.plot(days_list, spain_outputs, color='blue', label="Actual Confirmed Cases")
plt.plot(days_list, spain_pred_output, color='green', label="Predicted (Random Forest)")
plt.xlabel("Number of days since {}".format(first_day))
plt.ylabel("# of Cases")
plt.title("Spain Confirmed Cases vs Prediction from Random Forest Regressor (as of {})".format(last_day))
plt.legend()

# %%
# learning curve
rf_estimator_2 = RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
                      max_depth=100, max_features=3, max_leaf_nodes=None,
                      max_samples=None, min_impurity_decrease=0.0,
                      min_impurity_split=None, min_samples_leaf=3,
                      min_samples_split=8, min_weight_fraction_leaf=0.0,
                      n_estimators=100, n_jobs=None, oob_score=False,
                      random_state=None, verbose=0, warm_start=False)

train_sizes, train_scores, test_scores = learning_curve(estimator=rf_estimator_2, X=inputs, y=outputs,
                                       groups=None, 
                                       train_sizes=np.array([0.1, 0.33, 0.55, 0.78, 1. ]),
                                       cv=None, scoring=None, exploit_incremental_learning=False, 
                                       n_jobs=None, pre_dispatch='all', verbose=0, shuffle=True, 
                                       random_state=None, error_score=np.nan, return_times=False)

train_scores_mean = train_scores.mean(axis=1)
test_scores_mean = test_scores.mean(axis=1)

plt.plot(train_sizes, train_scores_mean, label='Training score')
plt.plot(train_sizes, test_scores_mean, label='Test score')

plt.ylabel('Score', fontsize=14)
plt.xlabel('Training set size', fontsize=14)
title = 'Learning curves for a ' + str(rf_estimator_2).split('(')[0] + ' model (Non normalized)'
plt.title(title, fontsize=18, y=1.03)
plt.legend()

# %% [markdown]
# # USING INCREMENTS AS OUTPUT

# %%
inputs = df[["Lat_norm", "Long_norm", "Num_days_from_begin_norm"]].values
inputs
# Out:
# array([[ 0.47108303,  0.59735963, -1.71718314],
#        [ 0.79830423, -0.03978737, -1.71718314],
#        [ 1.3112115 , -1.98320106, -1.71718314],
#        ...,
#        [-1.47205293,  0.07554281,  1.71718314],
#        [ 0.31790115,  1.38034566,  1.71718314],
#        [-1.65599721,  0.09994051,  1.71718314]])

# %%
# get the output for the machine learning algorithm (confirmed inc cases)
outputs = df["Confirmed_inc"].values
outputs
# Out:
# array([ 0.,  0.,  0., ..., 25.,  0.,  0.])

# %%
# split the data into training and testing sets
in_conf_train, in_conf_test, out_conf_train, out_conf_test = train_test_split(inputs, outputs, test_size=0.25, shuffle=True)

# NOTE: actually, the "testing" set will be used for "manual" testing and plotting, while the training set will be
# further divided in training and testing sets, in order to perform k-fold cross validation.

# %%
# do hyper parameter tuning with the Random Forest, using cross validation
param_grid = {
    'bootstrap': [True],
    'max_depth': [80, 90, 100, 110],
    'max_features': [2, 3],
    'min_samples_leaf': [3, 4, 5],
    'min_samples_split': [8, 10, 12],
    'n_estimators': [100, 200, 300, 1000]
}

start = time.time()

#search = GridSearchCV(estimator=rf, param_grid=param_grid, cv=3, n_jobs=-1, verbose=2)
search = RandomizedSearchCV(RandomForestRegressor(), param_grid, scoring='neg_mean_squared_error', cv=3, return_train_score=True, n_jobs=-1, n_iter=10, verbose=1)
search.fit(in_conf_train, out_conf_train)
end = time.time()
elapsed_time = end - start
print('Elapsed time: {}mins'.format(elapsed_time / 60))
print('Best score: {}'.format(search.best_score_))
print('Best parameters: {}'.format(search.best_params_))
search.best_estimator_
rf_estimator = search.best_estimator_
rf_estimator


#rf_estimator = RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
                      #max_depth=100, max_features=3, max_leaf_nodes=None,
                      #max_samples=None, min_impurity_decrease=0.0,
                      #min_impurity_split=None, min_samples_leaf=3,
                      #min_samples_split=8, min_weight_fraction_leaf=0.0,
                      #n_estimators=100, n_jobs=None, oob_score=False,
                      #random_state=None, verbose=0, warm_start=False)
#rf_estimator.fit(in_conf_train, out_conf_train)
# Out:
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  30 out of  30 | elapsed:  1.2min finished
# Elapsed time: 1.3914747993151346mins
# Best score: -96974.92134688182
# Best parameters: {'n_estimators': 200, 'min_samples_split': 8, 'min_samples_leaf': 3, 'max_features': 3, 'max_depth': 110, 'bootstrap': True}
# RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
#                       max_depth=110, max_features=3, max_leaf_nodes=None,
#                       max_samples=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=3,
#                       min_samples_split=8, min_weight_fraction_leaf=0.0,
#                       n_estimators=200, n_jobs=None, oob_score=False,
#                       random_state=None, verbose=0, warm_start=False)

# %%
rf_estimator_pred = rf_estimator.predict(in_conf_test)
plt.plot(out_conf_test)
plt.plot(rf_estimator_pred)
plt.legend(['Input Data', 'Random Forest Predictions (Inc as output)'])
print('MAE:', mean_absolute_error(out_conf_test, rf_estimator_pred))
print('MSE:',mean_squared_error(out_conf_test, rf_estimator_pred))
print('RMSE:', math.sqrt(mean_squared_error(out_conf_test, rf_estimator_pred)))
print('R^2:', r2_score(out_conf_test, rf_estimator_pred))
# Out:
# MAE: 33.836308034057
# MSE: 62363.64858640859
# RMSE: 249.72714827669137
# R^2: 0.9673223121514388

# %%
rf_estimator_2 = RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
                      max_depth=100, max_features=3, max_leaf_nodes=None,
                      max_samples=None, min_impurity_decrease=0.0,
                      min_impurity_split=None, min_samples_leaf=3,
                      min_samples_split=8, min_weight_fraction_leaf=0.0,
                      n_estimators=100, n_jobs=None, oob_score=False,
                      random_state=None, verbose=0, warm_start=False)

cv_scores = cross_val_score(rf_estimator_2, inputs, outputs, cv=10)
plt.hist(cv_scores)
plt.title('Average score: {}'.format(np.mean(cv_scores)))
# Out:
# Text(0.5, 1.0, 'Average score: 0.4180241179430043')

# %%
usa_df = df.loc[df["Country/Region"] == "US"]
usa_inputs = usa_df[["Lat_norm", "Long_norm", "Num_days_from_begin_norm"]].values
usa_outputs = usa_df["Confirmed_inc"].values
days_list = df["Num_days_from_begin"].unique()
usa_pred_output = rf_estimator.predict(usa_inputs)

first_day = df["Date"].min()
last_day = df["Date"].max()

diff_list = np.subtract(usa_outputs, usa_pred_output)

plt.bar(days_list, diff_list, color='blue', label="")
plt.show()

# %%
def calc_cumulative(in_list):
    out_list = []
    for idx, elem in enumerate(in_list):
        if idx == 0:
            out_list.append(elem)
        else:
            out_list.append(elem + out_list[idx - 1])
    return out_list

usa_outputs_cumulative = usa_df["Confirmed"].values
usa_pred_cumulative = calc_cumulative(usa_pred_output)

print('MAE:', mean_absolute_error(usa_outputs_cumulative, usa_pred_cumulative))
print('MSE:',mean_squared_error(usa_outputs_cumulative, usa_pred_cumulative))
print('RMSE:', math.sqrt(mean_squared_error(usa_outputs_cumulative, usa_pred_cumulative)))
print('R^2:', r2_score(usa_outputs_cumulative, usa_pred_cumulative))

plt.plot(days_list, usa_outputs_cumulative, color='blue', label="Actual Confirmed Cases")
plt.plot(days_list, usa_pred_cumulative, color='green', label="Predicted (Random Forest)")
plt.xlabel("Number of days since {}".format(first_day))
plt.ylabel("# of Cases")
plt.title("USA Confirmed Cases vs Prediction from Random Forest Regressor (as of {})".format(last_day))
plt.legend()

# %%
spain_df = df.loc[df["Country/Region"] == "Spain"]
spain_inputs = spain_df[["Lat_norm", "Long_norm", "Num_days_from_begin_norm"]].values
spain_outputs_cumulative = spain_df["Confirmed"].values
days_list = df["Num_days_from_begin"].unique()

spain_pred_output = rf_estimator.predict(spain_inputs) 
spain_pred_cumulative = calc_cumulative(spain_pred_output)

print('MAE:', mean_absolute_error(spain_outputs_cumulative, spain_pred_cumulative))
print('MSE:',mean_squared_error(spain_outputs_cumulative, spain_pred_cumulative))
print('RMSE:', math.sqrt(mean_squared_error(spain_outputs_cumulative, spain_pred_cumulative)))
print('R^2:', r2_score(spain_outputs_cumulative, spain_pred_cumulative))

first_day = df["Date"].min()
last_day = df["Date"].max()
plt.plot(days_list, spain_outputs_cumulative, color='blue', label="Actual Confirmed Cases")
plt.plot(days_list, spain_pred_cumulative, color='green', label="Predicted (Random Forest)")
plt.xlabel("Number of days since {}".format(first_day))
plt.ylabel("# of Cases")
plt.title("Spain Confirmed Cases vs Prediction from Random Forest Regressor (as of {})".format(last_day))
plt.legend()

# %%
brazil_df = df.loc[df["Country/Region"] == "Brazil"]
brazil_inputs = brazil_df[["Lat_norm", "Long_norm", "Num_days_from_begin_norm"]].values
brazil_outputs_cumulative = brazil_df["Confirmed"].values
days_list = df["Num_days_from_begin"].unique()

brazil_pred_output = rf_estimator.predict(brazil_inputs) 
brazil_pred_cumulative = calc_cumulative(brazil_pred_output)

print('MAE:', mean_absolute_error(brazil_outputs_cumulative, brazil_pred_cumulative))
print('MSE:',mean_squared_error(brazil_outputs_cumulative, brazil_pred_cumulative))
print('RMSE:', math.sqrt(mean_squared_error(brazil_outputs_cumulative, brazil_pred_cumulative)))
print('R^2:', r2_score(brazil_outputs_cumulative, brazil_pred_cumulative))

first_day = df["Date"].min()
last_day = df["Date"].max()
plt.plot(days_list, brazil_outputs_cumulative, color='blue', label="Actual Confirmed Cases")
plt.plot(days_list, brazil_pred_cumulative, color='green', label="Predicted (Random Forest)")
plt.xlabel("Number of days since {}".format(first_day))
plt.ylabel("# of Cases")
plt.title("Brazil Confirmed Cases vs Prediction from Random Forest Regressor (as of {})".format(last_day))
plt.legend()

# %%
# learning curve
rf_estimator_2 = RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
                      max_depth=100, max_features=3, max_leaf_nodes=None,
                      max_samples=None, min_impurity_decrease=0.0,
                      min_impurity_split=None, min_samples_leaf=3,
                      min_samples_split=8, min_weight_fraction_leaf=0.0,
                      n_estimators=100, n_jobs=None, oob_score=False,
                      random_state=None, verbose=0, warm_start=False)

train_sizes, train_scores, test_scores = learning_curve(estimator=rf_estimator_2, X=inputs, y=outputs,
                                       groups=None, 
                                       train_sizes=np.array([0.1, 0.33, 0.55, 0.78, 1. ]),
                                       cv=None, scoring=None, exploit_incremental_learning=False, 
                                       n_jobs=None, pre_dispatch='all', verbose=0, shuffle=True, 
                                       random_state=None, error_score=np.nan, return_times=False)

train_scores_mean = train_scores.mean(axis=1)
test_scores_mean = test_scores.mean(axis=1)

plt.plot(train_sizes, train_scores_mean, label='Training score')
plt.plot(train_sizes, test_scores_mean, label='Test score')

plt.ylabel('Score', fontsize=14)
plt.xlabel('Training set size', fontsize=14)
title = 'Learning curves for a ' + str(rf_estimator_2).split('(')[0] + ' model (Non normalized)'
plt.title(title, fontsize=18, y=1.03)
plt.legend()

# %% [markdown]
# # INCREASES AS INPUTS AND CUMULATIVE AS OUTPUT

# %%
# get the inputs of the data for the machine learning algorithm
new_df = df.loc[df["Confirmed_inc_day_before_norm"].notna()]

inputs = new_df[["Lat_norm", "Long_norm", "Num_days_from_begin_norm", "Confirmed_inc_day_before_norm"]].values
inputs
# Out:
# array([[ 0.47108303,  0.59735963, -1.68731909, -0.11699892],
#        [ 0.79830423, -0.03978737, -1.68731909, -0.11699892],
#        [ 1.3112115 , -1.98320106, -1.68731909, -0.11699892],
#        ...,
#        [-1.47205293,  0.07554281,  1.71718314, -0.11699892],
#        [ 0.31790115,  1.38034566,  1.71718314, -0.11699892],
#        [-1.65599721,  0.09994051,  1.71718314, -0.11308895]])

# %%
outputs = new_df["Confirmed"].values
outputs
# Out:
# array([   0,    0,    0, ...,  679, 1268,   42])

# %%
# split the data into training and testing sets
in_conf_train, in_conf_test, out_conf_train, out_conf_test = train_test_split(inputs, outputs, test_size=0.25, shuffle=True)

# NOTE: actually, the "testing" set will be used for "manual" testing and plotting, while the training set will be
# further divided in training and testing sets, in order to perform k-fold cross validation.

# %%
# do hyper parameter tuning with the Random Forest, using cross validation
param_grid = {
    'bootstrap': [True],
    'max_depth': [80, 90, 100, 110],
    'max_features': [2, 3],
    'min_samples_leaf': [3, 4, 5],
    'min_samples_split': [8, 10, 12],
    'n_estimators': [100, 200, 300, 1000]
}

start = time.time()

#search = GridSearchCV(estimator=rf, param_grid=param_grid, cv=3, n_jobs=-1, verbose=2)
search = RandomizedSearchCV(RandomForestRegressor(), param_grid, scoring='neg_mean_squared_error', cv=3, return_train_score=True, n_jobs=-1, n_iter=10, verbose=1)
search.fit(in_conf_train, out_conf_train)
end = time.time()
elapsed_time = end - start
print('Elapsed time: {}mins'.format(elapsed_time / 60))
print('Best score: {}'.format(search.best_score_))
print('Best parameters: {}'.format(search.best_params_))
search.best_estimator_
rf_estimator = search.best_estimator_
rf_estimator


#rf_estimator = RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
                      #max_depth=80, max_features=3, max_leaf_nodes=None,
                      #max_samples=None, min_impurity_decrease=0.0,
                      #min_impurity_split=None, min_samples_leaf=3,
                      #min_samples_split=8, min_weight_fraction_leaf=0.0,
                      #n_estimators=200, n_jobs=None, oob_score=False,
                      #random_state=None, verbose=0, warm_start=False)
#rf_estimator.fit(in_conf_train, out_conf_train)
# Out:
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  30 out of  30 | elapsed:  6.6min finished
# Elapsed time: 7.650863297780355mins
# Best score: -111318110.25138108
# Best parameters: {'n_estimators': 1000, 'min_samples_split': 8, 'min_samples_leaf': 4, 'max_features': 3, 'max_depth': 110, 'bootstrap': True}
# RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
#                       max_depth=110, max_features=3, max_leaf_nodes=None,
#                       max_samples=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=4,
#                       min_samples_split=8, min_weight_fraction_leaf=0.0,
#                       n_estimators=1000, n_jobs=None, oob_score=False,
#                       random_state=None, verbose=0, warm_start=False)

# %%
rf_estimator_pred = rf_estimator.predict(in_conf_test)
plt.plot(out_conf_test)
plt.plot(rf_estimator_pred)
plt.legend(['Input Data', 'Random Forest Predictions'])
print('MAE:', mean_absolute_error(out_conf_test, rf_estimator_pred))
print('MSE:',mean_squared_error(out_conf_test, rf_estimator_pred))
print('RMSE:', math.sqrt(mean_squared_error(out_conf_test, rf_estimator_pred)))
print('R^2:', r2_score(out_conf_test, rf_estimator_pred))
# Out:
# MAE: 728.1405717260625
# MSE: 32955278.966754194
# RMSE: 5740.668860573147
# R^2: 0.9777191695713597

# %%
rf_estimator_2 = RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
                      max_depth=100, max_features=3, max_leaf_nodes=None,
                      max_samples=None, min_impurity_decrease=0.0,
                      min_impurity_split=None, min_samples_leaf=3,
                      min_samples_split=8, min_weight_fraction_leaf=0.0,
                      n_estimators=100, n_jobs=None, oob_score=False,
                      random_state=None, verbose=0, warm_start=False)

cv_scores = cross_val_score(rf_estimator_2, inputs, outputs, cv=10)
plt.hist(cv_scores)
plt.title('Average score: {}'.format(np.mean(cv_scores)))
# Out:
# Text(0.5, 1.0, 'Average score: -5.520541479574781')

# %%
usa_df = new_df.loc[df["Country/Region"] == "US"]
usa_inputs = usa_df[["Lat_norm", "Long_norm", "Num_days_from_begin_norm", "Confirmed_inc_day_before_norm"]].values
usa_outputs = usa_df["Confirmed"].values
days_list = new_df["Num_days_from_begin"].unique()
usa_pred_output = rf_estimator.predict(usa_inputs) 

first_day = df["Date"].min()
last_day = df["Date"].max()

print('MAE:', mean_absolute_error(usa_outputs, usa_pred_output))
print('MSE:',mean_squared_error(usa_outputs, usa_pred_output))
print('RMSE:', math.sqrt(mean_squared_error(usa_outputs, usa_pred_output)))
print('R^2:', r2_score(usa_outputs, usa_pred_output))

plt.plot(days_list, usa_outputs, color='blue', label="Actual Confirmed Cases")
plt.plot(days_list, usa_pred_output, color='green', label="Predicted (Random Forest)")
plt.xlabel("Number of days since {}".format(first_day))
plt.ylabel("# of Cases")
plt.title("USA Confirmed Cases vs Prediction from Random Forest Regressor (as of {})".format(last_day))
plt.legend()

# %%
spain_df = new_df.loc[df["Country/Region"] == "Spain"]
spain_inputs = spain_df[["Lat_norm", "Long_norm", "Num_days_from_begin_norm", "Confirmed_inc_day_before_norm"]].values
spain_outputs = spain_df["Confirmed"].values
days_list = new_df["Num_days_from_begin"].unique()
spain_pred_output = rf_estimator.predict(spain_inputs) 

first_day = df["Date"].min()
last_day = df["Date"].max()

print('MAE:', mean_absolute_error(spain_outputs, spain_pred_output))
print('MSE:',mean_squared_error(spain_outputs, spain_pred_output))
print('RMSE:', math.sqrt(mean_squared_error(spain_outputs, spain_pred_output)))
print('R^2:', r2_score(spain_outputs, spain_pred_output))

plt.plot(days_list, spain_outputs, color='blue', label="Actual Confirmed Cases")
plt.plot(days_list, spain_pred_output, color='green', label="Predicted (Random Forest)")
plt.xlabel("Number of days since {}".format(first_day))
plt.ylabel("# of Cases")
plt.title("Spain Confirmed Cases vs Prediction from Random Forest Regressor (as of {})".format(last_day))
plt.legend()

# %%
# learning curve
rf_estimator_2 = RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
                      max_depth=100, max_features=3, max_leaf_nodes=None,
                      max_samples=None, min_impurity_decrease=0.0,
                      min_impurity_split=None, min_samples_leaf=3,
                      min_samples_split=8, min_weight_fraction_leaf=0.0,
                      n_estimators=100, n_jobs=None, oob_score=False,
                      random_state=None, verbose=0, warm_start=False)

train_sizes, train_scores, test_scores = learning_curve(estimator=rf_estimator_2, X=inputs, y=outputs,
                                       groups=None, 
                                       train_sizes=np.array([0.1, 0.33, 0.55, 0.78, 1. ]),
                                       cv=None, scoring=None, exploit_incremental_learning=False, 
                                       n_jobs=None, pre_dispatch='all', verbose=0, shuffle=True, 
                                       random_state=None, error_score=np.nan, return_times=False)

train_scores_mean = train_scores.mean(axis=1)
test_scores_mean = test_scores.mean(axis=1)

plt.plot(train_sizes, train_scores_mean, label='Training score')
plt.plot(train_sizes, test_scores_mean, label='Test score')

plt.ylabel('Score', fontsize=14)
plt.xlabel('Training set size', fontsize=14)
title = 'Learning curves for a ' + str(rf_estimator_2).split('(')[0] + ' model'
plt.title(title, fontsize=18, y=1.03)
plt.legend()

# %% [markdown]
# # INCREASES AS INPUTS AND INCREASES AS OUTPUT

# %%
inputs = new_df[["Lat_norm", "Long_norm", "Num_days_from_begin_norm", "Confirmed_inc_day_before_norm"]].values
inputs
# Out:
# array([[ 0.47108303,  0.59735963, -1.68731909, -0.11699892],
#        [ 0.79830423, -0.03978737, -1.68731909, -0.11699892],
#        [ 1.3112115 , -1.98320106, -1.68731909, -0.11699892],
#        ...,
#        [-1.47205293,  0.07554281,  1.71718314, -0.11699892],
#        [ 0.31790115,  1.38034566,  1.71718314, -0.11699892],
#        [-1.65599721,  0.09994051,  1.71718314, -0.11308895]])

# %%
outputs = new_df["Confirmed_inc"].values
outputs
# Out:
# array([ 0.,  0.,  0., ..., 25.,  0.,  0.])

# %%
# split the data into training and testing sets
in_conf_train, in_conf_test, out_conf_train, out_conf_test = train_test_split(inputs, outputs, test_size=0.25, shuffle=True)

# NOTE: actually, the "testing" set will be used for "manual" testing and plotting, while the training set will be
# further divided in training and testing sets, in order to perform k-fold cross validation.

# %%
# do hyper parameter tuning with the Random Forest, using cross validation
param_grid = {
    'bootstrap': [True],
    'max_depth': [80, 90, 100, 110],
    'max_features': [2, 3],
    'min_samples_leaf': [3, 4, 5],
    'min_samples_split': [8, 10, 12],
    'n_estimators': [100, 200, 300, 1000]
}

start = time.time()

#search = GridSearchCV(estimator=rf, param_grid=param_grid, cv=3, n_jobs=-1, verbose=2)
search = RandomizedSearchCV(RandomForestRegressor(), param_grid, scoring='neg_mean_squared_error', cv=3, return_train_score=True, n_jobs=-1, n_iter=10, verbose=1)
search.fit(in_conf_train, out_conf_train)
end = time.time()
elapsed_time = end - start
print('Elapsed time: {}mins'.format(elapsed_time / 60))
print('Best score: {}'.format(search.best_score_))
print('Best parameters: {}'.format(search.best_params_))
search.best_estimator_
rf_estimator = search.best_estimator_
rf_estimator


#rf_estimator = RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
                      #max_depth=80, max_features=3, max_leaf_nodes=None,
                      #max_samples=None, min_impurity_decrease=0.0,
                      #min_impurity_split=None, min_samples_leaf=3,
                      #min_samples_split=8, min_weight_fraction_leaf=0.0,
                      #n_estimators=200, n_jobs=None, oob_score=False,
                      #random_state=None, verbose=0, warm_start=False)
#rf_estimator.fit(in_conf_train, out_conf_train)
# Out:
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  30 out of  30 | elapsed:  4.3min finished
# Elapsed time: 4.39014980395635mins
# Best score: -94755.07268692134
# Best parameters: {'n_estimators': 200, 'min_samples_split': 12, 'min_samples_leaf': 3, 'max_features': 2, 'max_depth': 100, 'bootstrap': True}
# RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
#                       max_depth=100, max_features=2, max_leaf_nodes=None,
#                       max_samples=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=3,
#                       min_samples_split=12, min_weight_fraction_leaf=0.0,
#                       n_estimators=200, n_jobs=None, oob_score=False,
#                       random_state=None, verbose=0, warm_start=False)

# %%
rf_estimator_pred = rf_estimator.predict(in_conf_test)
plt.plot(out_conf_test)
plt.plot(rf_estimator_pred)
plt.legend(['Input Data', 'Random Forest Predictions (Inc as output)'])
print('MAE:', mean_absolute_error(out_conf_test, rf_estimator_pred))
print('MSE:',mean_squared_error(out_conf_test, rf_estimator_pred))
print('RMSE:', math.sqrt(mean_squared_error(out_conf_test, rf_estimator_pred)))
print('R^2:', r2_score(out_conf_test, rf_estimator_pred))
# Out:
# MAE: 39.01634195488072
# MSE: 136054.12504633327
# RMSE: 368.8551545611546
# R^2: 0.9053338221443361

# %%
rf_estimator_2 = RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
                      max_depth=100, max_features=3, max_leaf_nodes=None,
                      max_samples=None, min_impurity_decrease=0.0,
                      min_impurity_split=None, min_samples_leaf=3,
                      min_samples_split=8, min_weight_fraction_leaf=0.0,
                      n_estimators=100, n_jobs=None, oob_score=False,
                      random_state=None, verbose=0, warm_start=False)

cv_scores = cross_val_score(rf_estimator_2, inputs, outputs, cv=10)
plt.hist(cv_scores)
plt.title('Average score: {}'.format(np.mean(cv_scores)))
# Out:
# Text(0.5, 1.0, 'Average score: 0.5596623387612893')

# %%
usa_df = new_df.loc[df["Country/Region"] == "US"]
usa_inputs = usa_df[["Lat_norm", "Long_norm", "Num_days_from_begin_norm", "Confirmed_inc_day_before_norm"]].values
usa_outputs = usa_df["Confirmed_inc"].values
days_list = new_df["Num_days_from_begin"].unique()
usa_pred_output = rf_estimator.predict(usa_inputs)

first_day = df["Date"].min()
last_day = df["Date"].max()

diff_list = np.subtract(usa_outputs, usa_pred_output)

plt.bar(days_list, diff_list, color='blue', label="")
plt.show()

# %%
def calc_cumulative(in_list):
    out_list = []
    for idx, elem in enumerate(in_list):
        if idx == 0:
            out_list.append(elem)
        else:
            out_list.append(elem + out_list[idx - 1])
    return out_list

usa_outputs_cumulative = usa_df["Confirmed"].values
usa_pred_cumulative = calc_cumulative(usa_pred_output)

print('MAE:', mean_absolute_error(usa_outputs_cumulative, usa_pred_cumulative))
print('MSE:',mean_squared_error(usa_outputs_cumulative, usa_pred_cumulative))
print('RMSE:', math.sqrt(mean_squared_error(usa_outputs_cumulative, usa_pred_cumulative)))
print('R^2:', r2_score(usa_outputs_cumulative, usa_pred_cumulative))

plt.plot(days_list, usa_outputs_cumulative, color='blue', label="Actual Confirmed Cases")
plt.plot(days_list, usa_pred_cumulative, color='green', label="Predicted (Random Forest)")
plt.xlabel("Number of days since {}".format(first_day))
plt.ylabel("# of Cases")
plt.title("USA Confirmed Cases vs Prediction from Random Forest Regressor (as of {})".format(last_day))
plt.legend()

# %%
spain_df = new_df.loc[df["Country/Region"] == "Spain"]
spain_inputs = spain_df[["Lat_norm", "Long_norm", "Num_days_from_begin_norm", "Confirmed_inc_day_before_norm"]].values
spain_outputs_cumulative = spain_df["Confirmed"].values
days_list = new_df["Num_days_from_begin"].unique()

spain_pred_output = rf_estimator.predict(spain_inputs) 
spain_pred_cumulative = calc_cumulative(spain_pred_output)

first_day = df["Date"].min()
last_day = df["Date"].max()

print('MAE:', mean_absolute_error(spain_outputs_cumulative, spain_pred_cumulative))
print('MSE:',mean_squared_error(spain_outputs_cumulative, spain_pred_cumulative))
print('RMSE:', math.sqrt(mean_squared_error(spain_outputs_cumulative, spain_pred_cumulative)))
print('R^2:', r2_score(spain_outputs_cumulative, spain_pred_cumulative))

plt.plot(days_list, spain_outputs_cumulative, color='blue', label="Actual Confirmed Cases")
plt.plot(days_list, spain_pred_cumulative, color='green', label="Predicted (Random Forest)")
plt.xlabel("Number of days since {}".format(first_day))
plt.ylabel("# of Cases")
plt.title("Spain Confirmed Cases vs Prediction from Random Forest Regressor (as of {})".format(last_day))
plt.legend()

# %%
# learning curve
rf_estimator_2 = RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
                      max_depth=100, max_features=3, max_leaf_nodes=None,
                      max_samples=None, min_impurity_decrease=0.0,
                      min_impurity_split=None, min_samples_leaf=3,
                      min_samples_split=8, min_weight_fraction_leaf=0.0,
                      n_estimators=100, n_jobs=None, oob_score=False,
                      random_state=None, verbose=0, warm_start=False)

train_sizes, train_scores, test_scores = learning_curve(estimator=rf_estimator_2, X=inputs, y=outputs,
                                       groups=None, 
                                       train_sizes=np.array([0.1, 0.33, 0.55, 0.78, 1. ]),
                                       cv=None, scoring=None, exploit_incremental_learning=False, 
                                       n_jobs=None, pre_dispatch='all', verbose=0, shuffle=True, 
                                       random_state=None, error_score=np.nan, return_times=False)

train_scores_mean = train_scores.mean(axis=1)
test_scores_mean = test_scores.mean(axis=1)

plt.plot(train_sizes, train_scores_mean, label='Training score')
plt.plot(train_sizes, test_scores_mean, label='Test score')

plt.ylabel('Score', fontsize=14)
plt.xlabel('Training set size', fontsize=14)
title = 'Learning curves for a ' + str(rf_estimator_2).split('(')[0] + ' model'
plt.title(title, fontsize=18, y=1.03)
plt.legend()

# %% [markdown]
# # INCREASES AS OUTPUT, NON NORMALIZED INPUTS

# %%
inputs = df[["Lat", "Long", "Num_days_from_begin"]].values
inputs
# Out:
# array([[  33.    ,   65.    ,    0.    ],
#        [  41.1533,   20.1683,    0.    ],
#        [  53.9333, -116.5765,    0.    ],
#        ...,
#        [ -15.4167,   28.2833,  115.    ],
#        [  29.1832,  120.0934,  115.    ],
#        [ -20.    ,   30.    ,  115.    ]])

# %%
outputs = df["Confirmed_inc"].values
outputs
# Out:
# array([ 0.,  0.,  0., ..., 25.,  0.,  0.])

# %%
# split the data into training and testing sets
in_conf_train, in_conf_test, out_conf_train, out_conf_test = train_test_split(inputs, outputs, test_size=0.25, shuffle=True)

# NOTE: actually, the "testing" set will be used for "manual" testing and plotting, while the training set will be
# further divided in training and testing sets, in order to perform k-fold cross validation.

# %%
# do hyper parameter tuning with the Random Forest, using cross validation
param_grid = {
    'bootstrap': [True],
    'max_depth': [80, 90, 100, 110],
    'max_features': [2, 3],
    'min_samples_leaf': [3, 4, 5],
    'min_samples_split': [8, 10, 12],
    'n_estimators': [100, 200, 300, 1000]
}

start = time.time()

#search = GridSearchCV(estimator=rf, param_grid=param_grid, cv=3, n_jobs=-1, verbose=2)
search = RandomizedSearchCV(RandomForestRegressor(), param_grid, scoring='neg_mean_squared_error', cv=3, return_train_score=True, n_jobs=-1, n_iter=10, verbose=1)
search.fit(in_conf_train, out_conf_train)
end = time.time()
elapsed_time = end - start
print('Elapsed time: {}mins'.format(elapsed_time / 60))
print('Best score: {}'.format(search.best_score_))
print('Best parameters: {}'.format(search.best_params_))
search.best_estimator_
rf_estimator = search.best_estimator_
rf_estimator


#rf_estimator = RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
                      #max_depth=100, max_features=3, max_leaf_nodes=None,
                      #max_samples=None, min_impurity_decrease=0.0,
                      #min_impurity_split=None, min_samples_leaf=3,
                      #min_samples_split=8, min_weight_fraction_leaf=0.0,
                      #n_estimators=100, n_jobs=None, oob_score=False,
                      #random_state=None, verbose=0, warm_start=False)
#rf_estimator.fit(in_conf_train, out_conf_train)
# Out:
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  30 out of  30 | elapsed:  4.6min finished
# Elapsed time: 4.661027363936106mins
# Best score: -101026.1155871837
# Best parameters: {'n_estimators': 100, 'min_samples_split': 8, 'min_samples_leaf': 3, 'max_features': 2, 'max_depth': 100, 'bootstrap': True}
# RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
#                       max_depth=100, max_features=2, max_leaf_nodes=None,
#                       max_samples=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=3,
#                       min_samples_split=8, min_weight_fraction_leaf=0.0,
#                       n_estimators=100, n_jobs=None, oob_score=False,
#                       random_state=None, verbose=0, warm_start=False)

# %%
rf_estimator_pred = rf_estimator.predict(in_conf_test)
plt.plot(out_conf_test)
plt.plot(rf_estimator_pred)
plt.legend(['Input Data', 'Random Forest Predictions (Inc as output)'])
print('MAE:', mean_absolute_error(out_conf_test, rf_estimator_pred))
print('MSE:',mean_squared_error(out_conf_test, rf_estimator_pred))
print('RMSE:', math.sqrt(mean_squared_error(out_conf_test, rf_estimator_pred)))
print('R^2:', r2_score(out_conf_test, rf_estimator_pred))
# Out:
# MAE: 34.52571532836059
# MSE: 60557.9483089739
# RMSE: 246.0852460205079
# R^2: 0.9604715657879987

# %%
rf_estimator_2 = RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
                      max_depth=100, max_features=3, max_leaf_nodes=None,
                      max_samples=None, min_impurity_decrease=0.0,
                      min_impurity_split=None, min_samples_leaf=3,
                      min_samples_split=8, min_weight_fraction_leaf=0.0,
                      n_estimators=100, n_jobs=None, oob_score=False,
                      random_state=None, verbose=0, warm_start=False)

cv_scores = cross_val_score(rf_estimator_2, inputs, outputs, cv=10)
plt.hist(cv_scores)
plt.title('Average score: {}'.format(np.mean(cv_scores)))
# Out:
# Text(0.5, 1.0, 'Average score: 0.3827656587706672')

# %%
usa_df = df.loc[df["Country/Region"] == "US"]
usa_inputs = usa_df[["Lat", "Long", "Num_days_from_begin"]].values
usa_outputs = usa_df["Confirmed_inc"].values
days_list = df["Num_days_from_begin"].unique()
usa_pred_output = rf_estimator.predict(usa_inputs)

first_day = df["Date"].min()
last_day = df["Date"].max()

diff_list = np.subtract(usa_outputs, usa_pred_output)

plt.bar(days_list, diff_list, color='blue', label="")
plt.show()

# %%
def calc_cumulative(in_list):
    out_list = []
    for idx, elem in enumerate(in_list):
        if idx == 0:
            out_list.append(elem)
        else:
            out_list.append(elem + out_list[idx - 1])
    return out_list

usa_outputs_cumulative = usa_df["Confirmed"].values
usa_pred_cumulative = calc_cumulative(usa_pred_output)

print('MAE:', mean_absolute_error(usa_outputs_cumulative, usa_pred_cumulative))
print('MSE:',mean_squared_error(usa_outputs_cumulative, usa_pred_cumulative))
print('RMSE:', math.sqrt(mean_squared_error(usa_outputs_cumulative, usa_pred_cumulative)))
print('R^2:', r2_score(usa_outputs_cumulative, usa_pred_cumulative))

plt.plot(days_list, usa_outputs_cumulative, color='blue', label="Actual Confirmed Cases")
plt.plot(days_list, usa_pred_cumulative, color='green', label="Predicted (Random Forest)")
plt.xlabel("Number of days since {}".format(first_day))
plt.ylabel("# of Cases")
plt.title("USA Confirmed Cases vs Prediction from Random Forest Regressor (as of {})".format(last_day))
plt.legend()

# %%
spain_df = df.loc[df["Country/Region"] == "Spain"]
spain_inputs = spain_df[["Lat", "Long", "Num_days_from_begin"]].values
spain_outputs_cumulative = spain_df["Confirmed"].values
days_list = df["Num_days_from_begin"].unique()

spain_pred_output = rf_estimator.predict(spain_inputs) 
spain_pred_cumulative = calc_cumulative(spain_pred_output)

first_day = df["Date"].min()
last_day = df["Date"].max()

print('MAE:', mean_absolute_error(spain_outputs_cumulative, spain_pred_cumulative))
print('MSE:',mean_squared_error(spain_outputs_cumulative, spain_pred_cumulative))
print('RMSE:', math.sqrt(mean_squared_error(spain_outputs_cumulative, spain_pred_cumulative)))
print('R^2:', r2_score(spain_outputs_cumulative, spain_pred_cumulative))

plt.plot(days_list, spain_outputs_cumulative, color='blue', label="Actual Confirmed Cases")
plt.plot(days_list, spain_pred_cumulative, color='green', label="Predicted (Random Forest)")
plt.xlabel("Number of days since {}".format(first_day))
plt.ylabel("# of Cases")
plt.title("Spain Confirmed Cases vs Prediction from Random Forest Regressor (as of {})".format(last_day))
plt.legend()

# %%
brazil_df = df.loc[df["Country/Region"] == "Brazil"]
brazil_inputs = brazil_df[["Lat", "Long", "Num_days_from_begin"]].values
brazil_outputs_cumulative = brazil_df["Confirmed"].values
days_list = df["Num_days_from_begin"].unique()

brazil_pred_output = rf_estimator.predict(brazil_inputs) 
brazil_pred_cumulative = calc_cumulative(brazil_pred_output)

first_day = df["Date"].min()
last_day = df["Date"].max()

print('MAE:', mean_absolute_error(spain_outputs_cumulative, spain_pred_cumulative))
print('MSE:',mean_squared_error(spain_outputs_cumulative, spain_pred_cumulative))
print('RMSE:', math.sqrt(mean_squared_error(spain_outputs_cumulative, spain_pred_cumulative)))
print('R^2:', r2_score(spain_outputs_cumulative, spain_pred_cumulative))

plt.plot(days_list, brazil_outputs_cumulative, color='blue', label="Actual Confirmed Cases")
plt.plot(days_list, brazil_pred_cumulative, color='green', label="Predicted (Random Forest)")
plt.xlabel("Number of days since {}".format(first_day))
plt.ylabel("# of Cases")
plt.title("Brazil Confirmed Cases vs Prediction from Random Forest Regressor (as of {})".format(last_day))
plt.legend()

# %%
# learning curve
rf_estimator_2 = RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
                      max_depth=100, max_features=3, max_leaf_nodes=None,
                      max_samples=None, min_impurity_decrease=0.0,
                      min_impurity_split=None, min_samples_leaf=3,
                      min_samples_split=8, min_weight_fraction_leaf=0.0,
                      n_estimators=100, n_jobs=None, oob_score=False,
                      random_state=None, verbose=0, warm_start=False)

train_sizes, train_scores, test_scores = learning_curve(estimator=rf_estimator_2, X=inputs, y=outputs,
                                       groups=None, 
                                       train_sizes=np.array([0.1, 0.33, 0.55, 0.78, 1. ]),
                                       cv=None, scoring=None, exploit_incremental_learning=False, 
                                       n_jobs=None, pre_dispatch='all', verbose=0, shuffle=True, 
                                       random_state=None, error_score=np.nan, return_times=False)

train_scores_mean = train_scores.mean(axis=1)
test_scores_mean = test_scores.mean(axis=1)

plt.plot(train_sizes, train_scores_mean, label='Training score')
plt.plot(train_sizes, test_scores_mean, label='Test score')

plt.ylabel('Score', fontsize=14)
plt.xlabel('Training set size', fontsize=14)
title = 'Learning curves for a ' + str(rf_estimator_2).split('(')[0] + ' model (Non normalized)'
plt.title(title, fontsize=18, y=1.03)
plt.legend()

# %% [markdown]
# #### 3.1.2) Regression for Death Cases
# - - -

# %% [markdown]
# **(Will only use Increases as output and normalized inputs, as this approach got the best results)**

# %%
# get the inputs of the data for the machine learning algorithm
inputs = df[["Lat_norm", "Long_norm", "Num_days_from_begin_norm"]].values
inputs
# Out:
# array([[ 0.47108303,  0.59735963, -1.71718314],
#        [ 0.79830423, -0.03978737, -1.71718314],
#        [ 1.3112115 , -1.98320106, -1.71718314],
#        ...,
#        [-1.47205293,  0.07554281,  1.71718314],
#        [ 0.31790115,  1.38034566,  1.71718314],
#        [-1.65599721,  0.09994051,  1.71718314]])

# %%
# get the output for the machine learning algorithm (confirmed inc cases)
outputs = df["Deaths_inc"].values
outputs
# Out:
# array([0., 0., 0., ..., 0., 0., 0.])

# %%
# split the data into training and testing sets
in_conf_train, in_conf_test, out_conf_train, out_conf_test = train_test_split(inputs, outputs, test_size=0.25, shuffle=True)

# NOTE: actually, the "testing" set will be used for "manual" testing and plotting, while the training set will be
# further divided in training and testing sets, in order to perform k-fold cross validation.

# %%
# do hyper parameter tuning with the Random Forest, using cross validation
param_grid = {
    'bootstrap': [True],
    'max_depth': [80, 90, 100, 110],
    'max_features': [2, 3],
    'min_samples_leaf': [3, 4, 5],
    'min_samples_split': [8, 10, 12],
    'n_estimators': [100, 200, 300, 1000]
}

start = time.time()

#search = GridSearchCV(estimator=rf, param_grid=param_grid, cv=3, n_jobs=-1, verbose=2)
search = RandomizedSearchCV(RandomForestRegressor(), param_grid, scoring='neg_mean_squared_error', cv=3, return_train_score=True, n_jobs=-1, n_iter=10, verbose=1)
search.fit(in_conf_train, out_conf_train)
end = time.time()
elapsed_time = end - start
print('Elapsed time: {}mins'.format(elapsed_time / 60))
print('Best score: {}'.format(search.best_score_))
print('Best parameters: {}'.format(search.best_params_))
search.best_estimator_
rf_estimator = search.best_estimator_
rf_estimator


#rf_estimator = RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
                      #max_depth=100, max_features=3, max_leaf_nodes=None,
                      #max_samples=None, min_impurity_decrease=0.0,
                      #min_impurity_split=None, min_samples_leaf=3,
                      #min_samples_split=8, min_weight_fraction_leaf=0.0,
                      #n_estimators=100, n_jobs=None, oob_score=False,
                      #random_state=None, verbose=0, warm_start=False)
#rf_estimator.fit(in_conf_train, out_conf_train)
# Out:
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  30 out of  30 | elapsed:  6.7min finished
# Elapsed time: 7.324585636456807mins
# Best score: -674.6637204326119
# Best parameters: {'n_estimators': 300, 'min_samples_split': 8, 'min_samples_leaf': 3, 'max_features': 2, 'max_depth': 100, 'bootstrap': True}
# RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
#                       max_depth=100, max_features=2, max_leaf_nodes=None,
#                       max_samples=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=3,
#                       min_samples_split=8, min_weight_fraction_leaf=0.0,
#                       n_estimators=300, n_jobs=None, oob_score=False,
#                       random_state=None, verbose=0, warm_start=False)

# %%
rf_estimator_pred = rf_estimator.predict(in_conf_test)
plt.plot(out_conf_test)
plt.plot(rf_estimator_pred)
plt.legend(['Input Data', 'Random Forest Predictions (Inc as output)'])
print('MAE:', mean_absolute_error(out_conf_test, rf_estimator_pred))
print('MSE:',mean_squared_error(out_conf_test, rf_estimator_pred))
print('RMSE:', math.sqrt(mean_squared_error(out_conf_test, rf_estimator_pred)))
print('R^2:', r2_score(out_conf_test, rf_estimator_pred))
# Out:
# MAE: 2.7968313240286173
# MSE: 600.5353292498802
# RMSE: 24.505822354083126
# R^2: 0.923419713332914

# %%
rf_estimator_2 = RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
                      max_depth=100, max_features=3, max_leaf_nodes=None,
                      max_samples=None, min_impurity_decrease=0.0,
                      min_impurity_split=None, min_samples_leaf=3,
                      min_samples_split=8, min_weight_fraction_leaf=0.0,
                      n_estimators=100, n_jobs=None, oob_score=False,
                      random_state=None, verbose=0, warm_start=False)

cv_scores = cross_val_score(rf_estimator_2, inputs, outputs, cv=10)
plt.hist(cv_scores)
plt.title('Average score: {}'.format(np.mean(cv_scores)))
# Out:
# Text(0.5, 1.0, 'Average score: 0.48114645148938295')

# %%
usa_df = df.loc[df["Country/Region"] == "US"]
usa_inputs = usa_df[["Lat_norm", "Long_norm", "Num_days_from_begin_norm"]].values
usa_outputs = usa_df["Deaths_inc"].values
days_list = df["Num_days_from_begin"].unique()
usa_pred_output = rf_estimator.predict(usa_inputs)

first_day = df["Date"].min()
last_day = df["Date"].max()

diff_list = np.subtract(usa_outputs, usa_pred_output)

plt.bar(days_list, diff_list, color='blue', label="")
plt.show()

# %%
def calc_cumulative(in_list):
    out_list = []
    for idx, elem in enumerate(in_list):
        if idx == 0:
            out_list.append(elem)
        else:
            out_list.append(elem + out_list[idx - 1])
    return out_list

usa_outputs_cumulative = usa_df["Deaths"].values
usa_pred_cumulative = calc_cumulative(usa_pred_output)

print('MAE:', mean_absolute_error(usa_outputs_cumulative, usa_pred_cumulative))
print('MSE:',mean_squared_error(usa_outputs_cumulative, usa_pred_cumulative))
print('RMSE:', math.sqrt(mean_squared_error(usa_outputs_cumulative, usa_pred_cumulative)))
print('R^2:', r2_score(usa_outputs_cumulative, usa_pred_cumulative))

plt.plot(days_list, usa_outputs_cumulative, color='blue', label="Actual Confirmed Cases")
plt.plot(days_list, usa_pred_cumulative, color='green', label="Predicted (Random Forest)")
plt.xlabel("Number of days since {}".format(first_day))
plt.ylabel("# of Cases")
plt.title("USA Death Cases vs Prediction from Random Forest Regressor (as of {})".format(last_day))
plt.legend()

# %%
spain_df = df.loc[df["Country/Region"] == "Spain"]
spain_inputs = spain_df[["Lat_norm", "Long_norm", "Num_days_from_begin_norm"]].values
spain_outputs_cumulative = spain_df["Deaths"].values
days_list = df["Num_days_from_begin"].unique()

spain_pred_output = rf_estimator.predict(spain_inputs) 
spain_pred_cumulative = calc_cumulative(spain_pred_output)

first_day = df["Date"].min()
last_day = df["Date"].max()

print('MAE:', mean_absolute_error(spain_outputs_cumulative, spain_pred_cumulative))
print('MSE:',mean_squared_error(spain_outputs_cumulative, spain_pred_cumulative))
print('RMSE:', math.sqrt(mean_squared_error(spain_outputs_cumulative, spain_pred_cumulative)))
print('R^2:', r2_score(spain_outputs_cumulative, spain_pred_cumulative))

plt.plot(days_list, spain_outputs_cumulative, color='blue', label="Actual Confirmed Cases")
plt.plot(days_list, spain_pred_cumulative, color='green', label="Predicted (Random Forest)")
plt.xlabel("Number of days since {}".format(first_day))
plt.ylabel("# of Cases")
plt.title("Spain Deaths Cases vs Prediction from Random Forest Regressor (as of {})".format(last_day))
plt.legend()

# %%
brazil_df = df.loc[df["Country/Region"] == "Brazil"]
brazil_inputs = brazil_df[["Lat_norm", "Long_norm", "Num_days_from_begin_norm"]].values
brazil_outputs_cumulative = brazil_df["Deaths"].values
days_list = df["Num_days_from_begin"].unique()

brazil_pred_output = rf_estimator.predict(brazil_inputs) 
brazil_pred_cumulative = calc_cumulative(brazil_pred_output)

first_day = df["Date"].min()
last_day = df["Date"].max()

print('MAE:', mean_absolute_error(brazil_outputs_cumulative, brazil_pred_cumulative))
print('MSE:',mean_squared_error(brazil_outputs_cumulative, brazil_pred_cumulative))
print('RMSE:', math.sqrt(mean_squared_error(brazil_outputs_cumulative, brazil_pred_cumulative)))
print('R^2:', r2_score(brazil_outputs_cumulative, brazil_pred_cumulative))

plt.plot(days_list, brazil_outputs_cumulative, color='blue', label="Actual Confirmed Cases")
plt.plot(days_list, brazil_pred_cumulative, color='green', label="Predicted (Random Forest)")
plt.xlabel("Number of days since {}".format(first_day))
plt.ylabel("# of Cases")
plt.title("Brazil Deaths Cases vs Prediction from Random Forest Regressor (as of {})".format(last_day))
plt.legend()

# %%
russia_df = df.loc[df["Country/Region"] == "Russia"]
russia_inputs = russia_df[["Lat_norm", "Long_norm", "Num_days_from_begin_norm"]].values
russia_outputs_cumulative = russia_df["Deaths"].values
days_list = df["Num_days_from_begin"].unique()

russia_pred_output = rf_estimator.predict(russia_inputs) 
russia_pred_cumulative = calc_cumulative(russia_pred_output)

first_day = df["Date"].min()
last_day = df["Date"].max()

print('MAE:', mean_absolute_error(russia_outputs_cumulative, russia_pred_cumulative))
print('MSE:',mean_squared_error(russia_outputs_cumulative, russia_pred_cumulative))
print('RMSE:', math.sqrt(mean_squared_error(russia_outputs_cumulative, russia_pred_cumulative)))
print('R^2:', r2_score(russia_outputs_cumulative, russia_pred_cumulative))

plt.plot(days_list, russia_outputs_cumulative, color='blue', label="Actual Confirmed Cases")
plt.plot(days_list, russia_pred_cumulative, color='green', label="Predicted (Random Forest)")
plt.xlabel("Number of days since {}".format(first_day))
plt.ylabel("# of Cases")
plt.title("Russia Deaths Cases vs Prediction from Random Forest Regressor (as of {})".format(last_day))
plt.legend()

# %%
# learning curve
rf_estimator_2 = RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
                      max_depth=100, max_features=3, max_leaf_nodes=None,
                      max_samples=None, min_impurity_decrease=0.0,
                      min_impurity_split=None, min_samples_leaf=3,
                      min_samples_split=8, min_weight_fraction_leaf=0.0,
                      n_estimators=100, n_jobs=None, oob_score=False,
                      random_state=None, verbose=0, warm_start=False)

train_sizes, train_scores, test_scores = learning_curve(estimator=rf_estimator_2, X=inputs, y=outputs,
                                       groups=None, 
                                       train_sizes=np.array([0.1, 0.33, 0.55, 0.78, 1. ]),
                                       cv=None, scoring=None, exploit_incremental_learning=False, 
                                       n_jobs=None, pre_dispatch='all', verbose=0, shuffle=True, 
                                       random_state=None, error_score=np.nan, return_times=False)

train_scores_mean = train_scores.mean(axis=1)
test_scores_mean = test_scores.mean(axis=1)

plt.plot(train_sizes, train_scores_mean, label='Training score')
plt.plot(train_sizes, test_scores_mean, label='Test score')

plt.ylabel('Score', fontsize=14)
plt.xlabel('Training set size', fontsize=14)
title = 'Learning curves for a ' + str(rf_estimator_2).split('(')[0] + ' model'
plt.title(title, fontsize=18, y=1.03)
plt.legend()

# %% [markdown]
# #### 3.1.3) Regression for Recovered Cases
# - - -

# %% [markdown]
# **(Will only use Increases as output and normalized inputs, as this approach got the best results)**

# %%
recovered_df = df.loc[df["Recovered"].notna()]

# %%
# get the inputs of the data for the machine learning algorithm
inputs = recovered_df[["Lat_norm", "Long_norm", "Num_days_from_begin_norm"]].values
inputs
# Out:
# array([[ 0.47108303,  0.59735963, -1.71718314],
#        [ 0.79830423, -0.03978737, -1.71718314],
#        [ 0.27177561, -0.30283255, -1.71718314],
#        ...,
#        [-1.47205293,  0.07554281,  1.71718314],
#        [ 0.31790115,  1.38034566,  1.71718314],
#        [-1.65599721,  0.09994051,  1.71718314]])

# %%
# get the output for the machine learning algorithm (confirmed inc cases)
outputs = recovered_df["Recovered_inc"].values
outputs
# Out:
# array([ 0.,  0.,  0., ..., 59.,  0.,  0.])

# %%
# split the data into training and testing sets
in_conf_train, in_conf_test, out_conf_train, out_conf_test = train_test_split(inputs, outputs, test_size=0.25, shuffle=True)

# NOTE: actually, the "testing" set will be used for "manual" testing and plotting, while the training set will be
# further divided in training and testing sets, in order to perform k-fold cross validation.

# %%
# do hyper parameter tuning with the Random Forest, using cross validation
param_grid = {
    'bootstrap': [True],
    'max_depth': [80, 90, 100, 110],
    'max_features': [2, 3],
    'min_samples_leaf': [3, 4, 5],
    'min_samples_split': [8, 10, 12],
    'n_estimators': [100, 200, 300, 1000]
}

start = time.time()

#search = GridSearchCV(estimator=rf, param_grid=param_grid, cv=3, n_jobs=-1, verbose=2)
search = RandomizedSearchCV(RandomForestRegressor(), param_grid, scoring='neg_mean_squared_error', cv=3, return_train_score=True, n_jobs=-1, n_iter=10, verbose=1)
search.fit(in_conf_train, out_conf_train)
end = time.time()
elapsed_time = end - start
print('Elapsed time: {}mins'.format(elapsed_time / 60))
print('Best score: {}'.format(search.best_score_))
print('Best parameters: {}'.format(search.best_params_))
search.best_estimator_
rf_estimator = search.best_estimator_
rf_estimator


#rf_estimator = RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
                      #max_depth=100, max_features=3, max_leaf_nodes=None,
                      #max_samples=None, min_impurity_decrease=0.0,
                      #min_impurity_split=None, min_samples_leaf=3,
                      #min_samples_split=8, min_weight_fraction_leaf=0.0,
                      #n_estimators=100, n_jobs=None, oob_score=False,
                      #random_state=None, verbose=0, warm_start=False)
#rf_estimator.fit(in_conf_train, out_conf_train)
# Out:
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  30 out of  30 | elapsed:  8.6min finished
# Elapsed time: 8.692975437641143mins
# Best score: -102387.94399704994
# Best parameters: {'n_estimators': 100, 'min_samples_split': 10, 'min_samples_leaf': 3, 'max_features': 2, 'max_depth': 110, 'bootstrap': True}
# RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
#                       max_depth=110, max_features=2, max_leaf_nodes=None,
#                       max_samples=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=3,
#                       min_samples_split=10, min_weight_fraction_leaf=0.0,
#                       n_estimators=100, n_jobs=None, oob_score=False,
#                       random_state=None, verbose=0, warm_start=False)

# %%
rf_estimator_pred = rf_estimator.predict(in_conf_test)
plt.plot(out_conf_test)
plt.plot(rf_estimator_pred)
plt.legend(['Input Data', 'Random Forest Predictions (Inc as output)'])
print('MAE:', mean_absolute_error(out_conf_test, rf_estimator_pred))
print('MSE:',mean_squared_error(out_conf_test, rf_estimator_pred))
print('RMSE:', math.sqrt(mean_squared_error(out_conf_test, rf_estimator_pred)))
print('R^2:', r2_score(out_conf_test, rf_estimator_pred))
# Out:
# MAE: 29.825421227546002
# MSE: 70248.43763808985
# RMSE: 265.044218269499
# R^2: 0.6139011711951661

# %%
rf_estimator_2 = RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
                      max_depth=100, max_features=3, max_leaf_nodes=None,
                      max_samples=None, min_impurity_decrease=0.0,
                      min_impurity_split=None, min_samples_leaf=3,
                      min_samples_split=8, min_weight_fraction_leaf=0.0,
                      n_estimators=100, n_jobs=None, oob_score=False,
                      random_state=None, verbose=0, warm_start=False)

cv_scores = cross_val_score(rf_estimator_2, inputs, outputs, cv=10)
plt.hist(cv_scores)
plt.title('Average score: {}'.format(np.mean(cv_scores)))
# Out:
# Text(0.5, 1.0, 'Average score: -1.9157686952659005')

# %%
usa_df = recovered_df.loc[df["Country/Region"] == "US"]
usa_inputs = usa_df[["Lat_norm", "Long_norm", "Num_days_from_begin_norm"]].values
usa_outputs = usa_df["Recovered_inc"].values
days_list = recovered_df["Num_days_from_begin"].unique()
usa_pred_output = rf_estimator.predict(usa_inputs)

first_day = df["Date"].min()
last_day = df["Date"].max()

diff_list = np.subtract(usa_outputs, usa_pred_output)

plt.bar(days_list, diff_list, color='blue', label="")
plt.show()

# %%
def calc_cumulative(in_list):
    out_list = []
    for idx, elem in enumerate(in_list):
        if idx == 0:
            out_list.append(elem)
        else:
            out_list.append(elem + out_list[idx - 1])
    return out_list

usa_outputs_cumulative = usa_df["Recovered"].values
usa_pred_cumulative = calc_cumulative(usa_pred_output)

print('MAE:', mean_absolute_error(usa_outputs_cumulative, usa_pred_cumulative))
print('MSE:',mean_squared_error(usa_outputs_cumulative, usa_pred_cumulative))
print('RMSE:', math.sqrt(mean_squared_error(usa_outputs_cumulative, usa_pred_cumulative)))
print('R^2:', r2_score(usa_outputs_cumulative, usa_pred_cumulative))

plt.plot(days_list, usa_outputs_cumulative, color='blue', label="Actual Confirmed Cases")
plt.plot(days_list, usa_pred_cumulative, color='green', label="Predicted (Random Forest)")
plt.xlabel("Number of days since {}".format(first_day))
plt.ylabel("# of Cases")
plt.title("USA Recovered Cases vs Prediction from Random Forest Regressor (as of {})".format(last_day))
plt.legend()

# %%
spain_df = recovered_df.loc[df["Country/Region"] == "Spain"]
spain_inputs = spain_df[["Lat_norm", "Long_norm", "Num_days_from_begin_norm"]].values
spain_outputs_cumulative = spain_df["Recovered"].values
days_list = recovered_df["Num_days_from_begin"].unique()

spain_pred_output = rf_estimator.predict(spain_inputs) 
spain_pred_cumulative = calc_cumulative(spain_pred_output)

first_day = df["Date"].min()
last_day = df["Date"].max()

print('MAE:', mean_absolute_error(spain_outputs_cumulative, spain_pred_cumulative))
print('MSE:',mean_squared_error(spain_outputs_cumulative, spain_pred_cumulative))
print('RMSE:', math.sqrt(mean_squared_error(spain_outputs_cumulative, spain_pred_cumulative)))
print('R^2:', r2_score(spain_outputs_cumulative, spain_pred_cumulative))

plt.plot(days_list, spain_outputs_cumulative, color='blue', label="Actual Confirmed Cases")
plt.plot(days_list, spain_pred_cumulative, color='green', label="Predicted (Random Forest)")
plt.xlabel("Number of days since {}".format(first_day))
plt.ylabel("# of Cases")
plt.title("Spain Recovered Cases vs Prediction from Random Forest Regressor (as of {})".format(last_day))
plt.legend()

# %%
brazil_df = recovered_df.loc[df["Country/Region"] == "Brazil"]
brazil_inputs = brazil_df[["Lat_norm", "Long_norm", "Num_days_from_begin_norm"]].values
brazil_outputs_cumulative = brazil_df["Recovered"].values
days_list = recovered_df["Num_days_from_begin"].unique()

brazil_pred_output = rf_estimator.predict(brazil_inputs) 
brazil_pred_cumulative = calc_cumulative(brazil_pred_output)

first_day = df["Date"].min()
last_day = df["Date"].max()

print('MAE:', mean_absolute_error(brazil_outputs_cumulative, brazil_pred_cumulative))
print('MSE:',mean_squared_error(brazil_outputs_cumulative, brazil_pred_cumulative))
print('RMSE:', math.sqrt(mean_squared_error(brazil_outputs_cumulative, brazil_pred_cumulative)))
print('R^2:', r2_score(brazil_outputs_cumulative, brazil_pred_cumulative))

plt.plot(days_list, brazil_outputs_cumulative, color='blue', label="Actual Confirmed Cases")
plt.plot(days_list, brazil_pred_cumulative, color='green', label="Predicted (Random Forest)")
plt.xlabel("Number of days since {}".format(first_day))
plt.ylabel("# of Cases")
plt.title("Brazil Recovered Cases vs Prediction from Random Forest Regressor (as of {})".format(last_day))
plt.legend()

# %%
# learning curve
rf_estimator_2 = RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
                      max_depth=100, max_features=3, max_leaf_nodes=None,
                      max_samples=None, min_impurity_decrease=0.0,
                      min_impurity_split=None, min_samples_leaf=3,
                      min_samples_split=8, min_weight_fraction_leaf=0.0,
                      n_estimators=100, n_jobs=None, oob_score=False,
                      random_state=None, verbose=0, warm_start=False)

train_sizes, train_scores, test_scores = learning_curve(estimator=rf_estimator_2, X=inputs, y=outputs,
                                       groups=None, 
                                       train_sizes=np.array([0.1, 0.33, 0.55, 0.78, 1. ]),
                                       cv=None, scoring=None, exploit_incremental_learning=False, 
                                       n_jobs=None, pre_dispatch='all', verbose=0, shuffle=True, 
                                       random_state=None, error_score=np.nan, return_times=False)

train_scores_mean = train_scores.mean(axis=1)
test_scores_mean = test_scores.mean(axis=1)

plt.plot(train_sizes, train_scores_mean, label='Training score')
plt.plot(train_sizes, test_scores_mean, label='Test score')

plt.ylabel('Score', fontsize=14)
plt.xlabel('Training set size', fontsize=14)
title = 'Learning curves for a ' + str(rf_estimator_2).split('(')[0] + ' model'
plt.title(title, fontsize=18, y=1.03)
plt.legend()
